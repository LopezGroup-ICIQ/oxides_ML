# %%
"""Perform GNN model training with uncertainty quantification."""

import argparse
from os.path import isdir
import os
import time
import sys
sys.path.insert(0, "../src")

import torch
torch.backends.cudnn.deterministic = True 
import toml
from torch_geometric.seed import seed_everything
seed_everything(42)
import numpy as np
from numpy import random

from oxides_ml.training import create_loaders, scale_target, train_loop, test_loop, nll_loss, nll_loss_warmup
from oxides_ml.classes import EarlyStopper
from oxides_ml.nets import GameNetUQ
from oxides_ml.post_training import create_model_report
from oxides_ml.dataset import OxidesGraphDataset

if __name__ == "__main__":
    output_directory = "/home/tvanhout/oxides_ML/models/DATALOADERS/database_1"    # Root directory of loaders
    output_name = "Set4"                                                # Name of folder containing particular set

    if isdir("{}/{}".format(output_directory, output_name)):
        output_name = input("There is already a model with the chosen name in the provided directory, provide a new one: ")
    else:
        os.makedirs(os.path.join(output_directory, output_name), exist_ok=True)
        
    
    # Upload training hyperparameters from .toml file    
    hyperparameters = {'graph': {'target': 'adsorption_energy', 
                                 'structure': {'tolerance': 0.25, 'scaling_factor': 1.25, 'surface_order': 3}, 
                                 "features": {"adsorbate": False, "radical": False, "valence": False, "cn": True, "magnetization": False, "ads_height": False}}, 
                        'train': {'splits': 5, 'test_set': True, 'batch_size': 32, "key_elements": "none"}, 
                        'data': {'initial_state': True, 'augment': True, 'force_reload': True, 'vasp_directory': '/BACKUP/database_1', 'graph_dataset_path': '/home/tvanhout/oxides_ML/models/graph_datasets'}}
    vasp_directory = hyperparameters["data"]["vasp_directory"]
    graph_dataset_dir = hyperparameters["data"]["graph_dataset_path"]
    initial_state = hyperparameters['data']['initial_state']
    augment = hyperparameters['data']['augment']
    force_reload = hyperparameters['data']['force_reload']
    graph_settings = hyperparameters["graph"]
    train = hyperparameters["train"]

    # Select device
    device_dict = {}
    device = "cuda" if torch.cuda.is_available() else "cpu"
    if device == "cuda":
        print("Device name: {} (GPU)".format(torch.cuda.get_device_name(0)))
        device_dict["name"] = torch.cuda.get_device_name(0)
        device_dict["CudaDNN_enabled"] = torch.backends.cudnn.enabled
        device_dict["CUDNN_version"] = torch.backends.cudnn.version()
        device_dict["CUDA_version"] = torch.version.cuda
    else:
        print("Device name: CPU")
        device_dict["name"] = "CPU"     

    # Load graph dataset 
    dataset = OxidesGraphDataset(vasp_directory, graph_dataset_dir, graph_settings, initial_state=initial_state, augment=augment, force_reload=force_reload)
    ohe_elements = dataset.ohe_elements
    node_feature_list = dataset.node_feature_list
    num_node_features = len(node_feature_list)

    if train["key_elements"] == "none":
        # Create train/validation/test dataloaders (apply oversampling here for gas)
        train_loader, val_loader, test_loader = create_loaders(dataset,
                                                           batch_size=train["batch_size"],
                                                           split=train["splits"], 
                                                           test=train["test_set"], 
                                                           balance_func=None,) 
    else:
        # Create train/validation/test dataloaders (apply oversampling here for gas)
        train_loader, val_loader, test_loader = create_loaders(dataset,
                                                            batch_size=train["batch_size"],
                                                            split=train["splits"], 
                                                            test=train["test_set"], 
                                                            balance_func=None,
                                                            key_elements=train["key_elements"],) 
    
# Save dataloaders
torch.save(train_loader, "{}/{}/train_loader.pth".format(output_directory, output_name))
torch.save(val_loader, "{}/{}/val_loader.pth".format(output_directory, output_name))
torch.save(test_loader, "{}/{}/test_loader.pth".format(output_directory, output_name))
# Out:
# Device name: NVIDIA RTX A2000 12GB (GPU)
# Force reloading: deleting existing dataset at /home/tvanhout/oxides_ML/models/graph_datasets/database_1_adsorption_energy_025_125_3_False_False_False_True_False_False_initial_True
# Preloading adsorbate indices...
# Processing batch 0 to 400 ...
# Processing...
# C3H4O80Ru40: Fragmented adsorbate.
# CH3NO81Ru40: Fragmented adsorbate.
# Processing batch 400 to 800 ...
# CH2O83Ru40: Fragmented adsorbate.
# CH3NO82Ru40: Fragmented adsorbate.
# CH2O83Ru40: Fragmented adsorbate.
# C2H4O82Ru40: Fragmented adsorbate.
# CH2O82Ru40: Fragmented adsorbate.
# C2H4O82Ru40: Fragmented adsorbate.
# CH2O83Ru40: Fragmented adsorbate.
# CH3NO82Ru40: Fragmented adsorbate.
# CH2O83Ru40: Fragmented adsorbate.
# CH3NO82Ru40: Fragmented adsorbate.
# C2H4O82Ru40: Fragmented adsorbate.
# CH2O83Ru40: Fragmented adsorbate.
# CH3NO82Ru40: Fragmented adsorbate.
# CH3NO81Ru40: Fragmented adsorbate.
# CH3NO81Ru40: Fragmented adsorbate.
# C2H6O80Ru40S: Fragmented adsorbate.
# CH4O80Ru40S: Fragmented adsorbate.
# C2H6O80Ru40S: Fragmented adsorbate.
# CH4O80Ru40S: Fragmented adsorbate.
# C2H6Ir40O81: Fragmented adsorbate.
# C2H4Ir40O81: Fragmented adsorbate.
# CH2Ir40O81: Fragmented adsorbate.
# C3H8O80Ru40S: Fragmented adsorbate.
# CH2Ir40O81: Fragmented adsorbate.
# CH4Ir40O81: Fragmented adsorbate.
# CH4Ir40O81: Fragmented adsorbate.
# C2H4Ir40O81: Fragmented adsorbate.
# C2H6Ir40O81: Fragmented adsorbate.
# CH4Ir40O81: Fragmented adsorbate.
# Processing batch 800 to 1200 ...
# C3H8Ir40O80: Fragmented adsorbate.
# C3H6Ir40O80: Fragmented adsorbate.
# C2H6Ir40O80: Fragmented adsorbate.
# C2H5Ir40NO81: Fragmented adsorbate.
# C2H2Ir40O80: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# CH4Ir40N2O80: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# C3H4Ir40O80: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# CH4Ir40N2O80: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# C2H6Ir40N2O80: Fragmented adsorbate.
# C3H9Ir40NO80: Fragmented adsorbate.
# CH3Ir40NO82: Fragmented adsorbate.
# CH3Ir40NO82: Fragmented adsorbate.
# CH2Ir40O83: Fragmented adsorbate.
# CH2Ir40O83: Fragmented adsorbate.
# C2H4Ir40O82: Fragmented adsorbate.
# C2H4Ir40O82: Fragmented adsorbate.
# CH3Ir40NO82: Fragmented adsorbate.
# CH2Ir40O83: Fragmented adsorbate.
# CH3Ir40NO82: Fragmented adsorbate.
# CH2Ir40O82: Fragmented adsorbate.
# CH3Ir40NO82: Fragmented adsorbate.
# CH2Ir40O83: Fragmented adsorbate.
# CH3Ir40NO82: Fragmented adsorbate.
# C2H4Ir40O82: Fragmented adsorbate.
# C2H4Ir40O82: Fragmented adsorbate.
# CH3Ir40NO82: Fragmented adsorbate.
# CH2Ir40O82: Fragmented adsorbate.
# C2H4Ir40O82: Fragmented adsorbate.
# CH2Ir40O83: Fragmented adsorbate.
# CH2Ir40O82: Fragmented adsorbate.
# C2H5Ir40NO80: Fragmented adsorbate.
# CH2Ir40O83: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.CH2Ir40O82: Fragmented adsorbate.
#
# C2H5Ir40NO80: Fragmented adsorbate.
# CH2Ir40O82: Fragmented adsorbate.
# C3H9Ir40NO80: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# CH3Ir40NO81: Fragmented adsorbate.
# Processing batch 1200 to 1600 ...
# C2H6Ir40O80S: Fragmented adsorbate.
# C2H6Ir40O80S: Fragmented adsorbate.
# C2H6Ir40O80S: Fragmented adsorbate.
# C2H6Ir40O80S: Fragmented adsorbate.
# C2H6Ir40O80S: Fragmented adsorbate.
# CH4Ir40O80S: Fragmented adsorbate.
# C2H6Ir40O80S: Fragmented adsorbate.
# CH4Ir40O80S: Fragmented adsorbate.
# CH4Ir40O80S: Fragmented adsorbate.
# C3H6Ir40O80S: Fragmented adsorbate.
# C3H8Ir40O80S: Fragmented adsorbate.
# C3H8Ir40O80S: Fragmented adsorbate.
# C3H8Ir40O80S: Fragmented adsorbate.
# C3H8Ir40O80S: Fragmented adsorbate.C3H8Ir40O80S: Fragmented adsorbate.
#
# C3H8Ir40O80S: Fragmented adsorbate.
# C3H8Ir40O80S: Fragmented adsorbate.
# C3H8Ir40O80S: Fragmented adsorbate.
# Isomorphism detected for C2H4O81Ru40
# Isomorphism detected for C2H4O81Ru40
# Isomorphism detected for CH2O81Ru40
# Isomorphism detected for CH4O81Ru40
# Isomorphism detected for CH4O81Ru40
# Isomorphism detected for CH4O81Ru40
# Isomorphism detected for CH4O81Ru40
# Isomorphism detected for CH4O81Ru40
# Isomorphism detected for CH4O81Ru40
# Isomorphism detected for CH4O81Ru40
# Isomorphism detected for CH4O81Ru40
# Isomorphism detected for C3H8O81Ru40
# Isomorphism detected for C3H6O81Ru40
# Isomorphism detected for C2H6O80Ru40
# Isomorphism detected for C2H4O80Ru40
# Isomorphism detected for CH4O80Ru40
# Isomorphism detected for CH4O80Ru40
# Isomorphism detected for CH4O80Ru40
# Isomorphism detected for CH4O80Ru40
# Isomorphism detected for C3H4O80Ru40
# Isomorphism detected for C3H8O80Ru40
# Isomorphism detected for C3H8O80Ru40
# Isomorphism detected for C3H8O80Ru40
# Isomorphism detected for C3H6O80Ru40
# Isomorphism detected for C3H6O80Ru40
# Isomorphism detected for C3H6O80Ru40
# Isomorphism detected for C3H6O80Ru40
# Isomorphism detected for C2H7NO80Ru40
# Isomorphism detected for C2H7NO80Ru40
# Isomorphism detected for C2H7NO80Ru40
# Isomorphism detected for CH5NO80Ru40
# Isomorphism detected for CH5NO80Ru40
# Isomorphism detected for CH5NO80Ru40
# Isomorphism detected for CH5NO80Ru40
# Isomorphism detected for C3H9NO80Ru40
# Isomorphism detected for C3H9NO80Ru40
# Isomorphism detected for C3H9NO80Ru40
# Isomorphism detected for CH3NO82Ru40
# Isomorphism detected for C2H5NO80Ru40
# Isomorphism detected for C2H5NO80Ru40
# Isomorphism detected for CH3NO80Ru40
# Isomorphism detected for CH3NO81Ru40
# Isomorphism detected for CH3NO81Ru40
# Isomorphism detected for C3H6O80Ru40S
# Isomorphism detected for C3H8O80Ru40S
# Isomorphism detected for C3H8O80Ru40S
# Isomorphism detected for C2H4Ir40O81
# Isomorphism detected for C2H4Ir40O81
# Isomorphism detected for CH2Ir40O81
# Isomorphism detected for CH4Ir40O81
# Isomorphism detected for CH4Ir40O81
# Isomorphism detected for C3H6Ir40O81
# Isomorphism detected for C2H6Ir40O81
# Isomorphism detected for C2H2Ir40O80
# Isomorphism detected for C2H2Ir40O80
# Isomorphism detected for C2H4Ir40O80
# Isomorphism detected for C3H4Ir40O80
# Isomorphism detected for C3H6Ir40O80
# Isomorphism detected for C2H5Ir40NO81
# Isomorphism detected for C2H5Ir40NO81
# Isomorphism detected for C2H5Ir40NO81
# Isomorphism detected for C2H5Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for C2H6Ir40N2O80
# Isomorphism detected for C2H6Ir40N2O80
# Isomorphism detected for CH4Ir40N2O80
# Isomorphism detected for CH4Ir40N2O80
# Isomorphism detected for CH4Ir40N2O80
# Isomorphism detected for CH5Ir40NO80
# Isomorphism detected for C3H9Ir40NO80
# Isomorphism detected for C3H9Ir40NO80
# Isomorphism detected for C3H9Ir40NO80
# Isomorphism detected for C3H9Ir40NO80
# Isomorphism detected for CH3Ir40NO82
# Isomorphism detected for CH3Ir40NO82
# Isomorphism detected for CH3Ir40NO82
# Isomorphism detected for CH3Ir40NO82
# Isomorphism detected for CH3Ir40NO82
# Isomorphism detected for C2H4Ir40O82
# Isomorphism detected for CH2Ir40O83
# Isomorphism detected for CH2Ir40O83
# Isomorphism detected for CH2Ir40O82
# Isomorphism detected for CH2Ir40O82
# Isomorphism detected for C2H5Ir40NO80
# Isomorphism detected for CH3Ir40NO80
# Isomorphism detected for CH3Ir40NO80
# Isomorphism detected for C2H5Ir40NO80
# Isomorphism detected for C2H5Ir40NO80
# Isomorphism detected for C2H5Ir40NO80
# Isomorphism detected for C2H5Ir40NO80
# Isomorphism detected for C3H7Ir40NO80
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for CH3Ir40NO81
# Isomorphism detected for C2H6Ir40O80S
# Isomorphism detected for C2H4Ir40O80S
# Isomorphism detected for C2H4Ir40O80S
# Isomorphism detected for C2H6Ir40O80S
# Isomorphism detected for CH4Ir40O80S
# Isomorphism detected for CH4Ir40O80S
# Isomorphism detected for CH4Ir40O80S
# Isomorphism detected for C3H6Ir40O80S
# Isomorphism detected for C3H6Ir40O80S
# Isomorphism detected for C3H8Ir40O80S
# Isomorphism detected for C3H8Ir40O80S
# Isomorphism detected for C3H8Ir40O80S
# Isomorphism detected for C3H8Ir40O80S
# Graph dataset size: 1213
# Done!
# Data split (train/val/test): 60/20/20 %
# Training data = 729 Validation data = 242 Test data = 242 (Total = 1213)
